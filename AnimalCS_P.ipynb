# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
df1 = pd.read_csv('animal.csv')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sample Number  344 non-null    int64
#  1   Species        344 non-null    object
#  2   Region         344 non-null    object
#  3   Island         344 non-null    object
#  4   paw_length     342 non-null    float64
#  5   paw_depth      342 non-null    float64
#  6   body_height    342 non-null    float64
#  7   body_mass      342 non-null    float64
#  8   gender         334 non-null    object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 24.3+ KB

# %%
df1.head()
# Out:
#    Sample Number                                 Species  Region     Island  \
# 0              1  Adelie Polar_bear (Pygoscelis adeliae)  Anvers  Torgersen
# 1              2  Adelie Polar_bear (Pygoscelis adeliae)  Anvers  Torgersen
# 2              3  Adelie Polar_bear (Pygoscelis adeliae)  Anvers  Torgersen
# 3              4  Adelie Polar_bear (Pygoscelis adeliae)  Anvers  Torgersen
# 4              5  Adelie Polar_bear (Pygoscelis adeliae)  Anvers  Torgersen
#
#    paw_length  paw_depth  body_height  body_mass  gender
# 0        39.1       18.7        181.0     3750.0    MALE
# 1        39.5       17.4        186.0     3800.0  FEMALE
# 2        40.3       18.0        195.0     3250.0  FEMALE
# 3         NaN        NaN          NaN        NaN     NaN
# 4        36.7       19.3        193.0     3450.0  FEMALE

# %%
df = df1.dropna()
df.head()
# Out:
#    Sample Number                                 Species  Region     Island  \
# 0              1  Adelie Polar_bear (Pygoscelis adeliae)  Anvers  Torgersen
# 1              2  Adelie Polar_bear (Pygoscelis adeliae)  Anvers  Torgersen
# 2              3  Adelie Polar_bear (Pygoscelis adeliae)  Anvers  Torgersen
# 4              5  Adelie Polar_bear (Pygoscelis adeliae)  Anvers  Torgersen
# 5              6  Adelie Polar_bear (Pygoscelis adeliae)  Anvers  Torgersen
#
#    paw_length  paw_depth  body_height  body_mass  gender
# 0        39.1       18.7        181.0     3750.0    MALE
# 1        39.5       17.4        186.0     3800.0  FEMALE
# 2        40.3       18.0        195.0     3250.0  FEMALE
# 4        36.7       19.3        193.0     3450.0  FEMALE
# 5        39.3       20.6        190.0     3650.0    MALE

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 334 entries, 0 to 343
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sample Number  334 non-null    int64
#  1   Species        334 non-null    object
#  2   Region         334 non-null    object
#  3   Island         334 non-null    object
#  4   paw_length     334 non-null    float64
#  5   paw_depth      334 non-null    float64
#  6   body_height    334 non-null    float64
#  7   body_mass      334 non-null    float64
#  8   gender         334 non-null    object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 26.1+ KB

# %%
df.describe()
# Out:
#        Sample Number  paw_length   paw_depth  body_height    body_mass
# count     334.000000  334.000000  334.000000   334.000000   334.000000
# mean       63.805389   43.994311   17.160479   201.014970  4209.056886
# std        40.246924    5.460521    1.967909    14.022175   804.836129
# min         1.000000   32.100000   13.100000   172.000000  2700.000000
# 25%        30.250000   39.500000   15.600000   190.000000  3550.000000
# 50%        58.500000   44.500000   17.300000   197.000000  4050.000000
# 75%        95.750000   48.575000   18.700000   213.000000  4793.750000
# max       152.000000   59.600000   21.500000   231.000000  6300.000000

# %%
df.corr()
# Out:
#                Sample Number  paw_length  paw_depth  body_height  body_mass
# Sample Number       1.000000   -0.262955  -0.011984     0.024201  -0.021748
# paw_length         -0.262955    1.000000  -0.228640     0.652126   0.589066
# paw_depth          -0.011984   -0.228640   1.000000    -0.578730  -0.472987
# body_height         0.024201    0.652126  -0.578730     1.000000   0.873211
# body_mass          -0.021748    0.589066  -0.472987     0.873211   1.000000

# %%
cor = df.corr()
sns.heatmap(cor)

# %%
cols = ['paw_length', 'paw_depth', 'body_height', 'body_mass_g']
m = df[df.gender == 'MALE']
f = df[df.gender == 'FEMALE']
m
# Out:
#      Sample Number                                 Species  Region     Island  \
# 0                1  Adelie Polar_bear (Pygoscelis adeliae)  Anvers  Torgersen
# 5                6  Adelie Polar_bear (Pygoscelis adeliae)  Anvers  Torgersen
# 7                8  Adelie Polar_bear (Pygoscelis adeliae)  Anvers  Torgersen
# 13              14  Adelie Polar_bear (Pygoscelis adeliae)  Anvers  Torgersen
# 14              15  Adelie Polar_bear (Pygoscelis adeliae)  Anvers  Torgersen
# ..             ...                                     ...     ...        ...
# 333            114    Gentoo Polar_bear (Pygoscelis papua)  Anvers     Biscoe
# 335            116    Gentoo Polar_bear (Pygoscelis papua)  Anvers     Biscoe
# 337            118    Gentoo Polar_bear (Pygoscelis papua)  Anvers     Biscoe
# 341            122    Gentoo Polar_bear (Pygoscelis papua)  Anvers     Biscoe
# 343            124    Gentoo Polar_bear (Pygoscelis papua)  Anvers     Biscoe
#
# ...

# %%
f
# Out:
#      Sample Number                                 Species  Region     Island  \
# 1                2  Adelie Polar_bear (Pygoscelis adeliae)  Anvers  Torgersen
# 2                3  Adelie Polar_bear (Pygoscelis adeliae)  Anvers  Torgersen
# 4                5  Adelie Polar_bear (Pygoscelis adeliae)  Anvers  Torgersen
# 6                7  Adelie Polar_bear (Pygoscelis adeliae)  Anvers  Torgersen
# 12              13  Adelie Polar_bear (Pygoscelis adeliae)  Anvers  Torgersen
# ..             ...                                     ...     ...        ...
# 332            113    Gentoo Polar_bear (Pygoscelis papua)  Anvers     Biscoe
# 334            115    Gentoo Polar_bear (Pygoscelis papua)  Anvers     Biscoe
# 338            119    Gentoo Polar_bear (Pygoscelis papua)  Anvers     Biscoe
# 340            121    Gentoo Polar_bear (Pygoscelis papua)  Anvers     Biscoe
# 342            123    Gentoo Polar_bear (Pygoscelis papua)  Anvers     Biscoe
#
# ...

# %%
sns.countplot(x = df.gender)

# %%
sns.countplot(x = df.Species)

# %%
sns.countplot(x = df.Island)

# %%
sns.pairplot(df,hue='Species', height=2)

# %%
plt.title("Histogram for Bill Length")
plt.hist(df.paw_length)
plt.show()

# %%
plt.title("Histogram for Bill Depth")
plt.hist(df.paw_depth)
plt.show()

# %%
plt.title("Histogram for Flipper Length")
plt.hist(df.body_height)
plt.show()

# %%
plt.title("Histogram for Body Mass")
plt.hist(df.body_mass)
plt.show()

# %%
from sklearn.decomposition import PCA 
from sklearn.preprocessing import StandardScaler 
import matplotlib.pyplot as plt 
features =['paw_length', 'paw_depth', 'body_height', 'body_mass'] 
x = df.loc[:,features].values 
y = df.loc[:,['Species']].values 
x = StandardScaler().fit_transform(x)
pd.DataFrame(data = x, columns = features).head()
# Out:
#    paw_length  paw_depth  body_height  body_mass
# 0   -0.897653   0.783487    -1.429521  -0.571229
# 1   -0.824290   0.121896    -1.072408  -0.509011
# 2   -0.677564   0.427246    -0.429605  -1.193405
# 3   -1.337831   1.088836    -0.572450  -0.944535
# 4   -0.860972   1.750427    -0.786718  -0.695664

# %%
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])
principalDf.head(5)
# Out:
#    principal component 1  principal component 2
# 0              -1.858488               0.031676
# 1              -1.320722              -0.443473
# 2              -1.381688              -0.161086
# 3              -1.890897              -0.014556
# 4              -1.925839               0.816179

# %%
finalDf = pd.concat([principalDf, df[['Species']]], axis = 1)
finalDf.head(5)
# Out:
#    principal component 1  principal component 2  \
# 0              -1.858488               0.031676
# 1              -1.320722              -0.443473
# 2              -1.381688              -0.161086
# 3              -1.890897              -0.014556
# 4              -1.925839               0.816179
#
#                                   Species
# 0  Adelie Polar_bear (Pygoscelis adeliae)
# 1  Adelie Polar_bear (Pygoscelis adeliae)
# 2  Adelie Polar_bear (Pygoscelis adeliae)
# 3                                     NaN
# 4  Adelie Polar_bear (Pygoscelis adeliae)

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 Component PCA', fontsize = 20)


targets = ['Adelie Polar_bear (Pygoscelis adeliae)', 'Gentoo Polar_bear (Pygoscelis papua)', 'Chinstrap Polar_bear (Pygoscelis antarctica)']
colors = ['r', 'g', 'b']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['Species'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
               , finalDf.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()
